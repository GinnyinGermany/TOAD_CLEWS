# %%
import matplotlib.pyplot as plt
import xarray as xr

plt.rcParams["figure.dpi"] = 300
plt.rcParams["figure.figsize"] = (12, 6)

# %%
import intake
import intake_esm
url = intake_esm.tutorial.get_url('google_cmip6')
print(url)
# Out:
# https://raw.githubusercontent.com/intake/intake-esm/main/tutorial-catalogs/GOOGLE-CMIP6.json

# %%
variables = col.unique("variable_id")
print(variables['variable_id']['values'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 variables = col.unique("variable_id")
#       2 print(variables['variable_id']['values'])
#
# NameError: name 'col' is not defined
